# %% [markdown]
# # **My First ML Project**

# %% [markdown]
# # **Load data**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/delaney_solubility_with_descriptors.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# # **Data prepration**

# %% [markdown]
# ## Data sepration as X and Y

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
X = df.drop('logS', axis=1)
X
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
X_train
# Out:
#      MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 107  3.14280  112.216                5.0            0.000000
# 378 -2.07850  142.070                0.0            0.000000
# 529 -0.47730  168.152                0.0            0.000000
# 546 -0.86740  154.125                0.0            0.000000
# 320  1.62150  100.161                2.0            0.000000
# ..       ...      ...                ...                 ...
# 802  3.00254  250.301                1.0            0.842105
# 53   2.13860   82.146                3.0            0.000000
# 350  5.76304  256.348                0.0            0.900000
# 79   3.89960  186.339               10.0            0.000000
# 792  2.52334  310.297                3.0            0.300000
#
# [915 rows x 4 columns]

# %%
X_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 1114  1.76210  478.513                4.0            0.000000
# 427   6.32820  276.338                0.0            1.000000
# 711   0.04430  218.205                5.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# 948   3.56010  318.328                2.0            0.750000
#
# [229 rows x 4 columns]

# %% [markdown]
# # **Model Builsing**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# **Training the model**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Applying the model to make a prediction**

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
y_lr_train_pred
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %%
y_lr_test_pred
# Out:
# array([-3.05722870e+00, -7.77785827e+00, -2.55016650e+00, -2.01523582e+00,
#        -2.06375990e+00, -9.99672215e-01, -5.94603364e-01, -5.53626003e-01,
#        -5.72200956e+00, -3.94006681e+00, -3.95496755e+00, -2.29737009e+00,
#        -1.48980354e+00, -1.48988982e+00, -4.64510806e+00, -1.90396018e+00,
#        -1.51566313e+00, -3.16424605e+00, -3.70863920e+00, -5.58105660e+00,
#        -3.25038467e+00, -5.04235077e+00, -5.69194881e+00, -2.14339849e+00,
#        -4.35689341e+00, -5.03964756e+00, -3.10383618e+00, -4.40286964e+00,
#        -4.21276272e+00,  5.56508349e-01, -1.45537678e+00, -4.41027396e+00,
#        -2.59668773e+00, -1.53336276e+00, -5.55749874e-01, -1.67111795e+00,
#        -2.78163675e+00, -3.15395565e+00, -5.27083361e+00, -1.75321446e+00,
#        -1.53350725e+00, -2.01255666e+00, -6.57559167e+00, -7.89433046e+00,
#        -5.76437127e+00, -4.16422068e+00, -3.43694663e+00,  1.43834212e+00,
# ...

# %% [markdown]
# **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print("LR MSE (Train): ", lr_train_mse)
print("LR R2 (Train): ", lr_train_r2)
print("LR MSE (Test): ", lr_test_mse)
print("LR R2 (Test): ", lr_test_r2)
# Out:
# LR MSE (Train):  1.0075362951093687
# LR R2 (Train):  0.7645051774663391
# LR MSE (Test):  1.0206953660861033
# LR R2 (Test):  0.7891616188563282

# %%
lr_results = pd.DataFrame(["Linear regression", lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth = 2, random_state = 100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### **Applying the model to make a prediction**

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# ### **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(["Random forest", rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random forest     1.028228    0.759669  1.407688  0.709223

# %% [markdown]
# ## **Model comparision**

# %%
df_models = pd.concat([lr_results, rf_results], axis = 0)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162
# 0      Random forest     1.028228    0.759669  1.407688  0.709223

# %%
df_models.reset_index(drop = True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     1.007536    0.764505  1.020695  0.789162
# 1      Random forest     1.028228    0.759669  1.407688  0.709223

# %% [markdown]
# # **Data visualization of predicted results**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.scatter(x = y_train, y = y_lr_train_pred, c = "#7CAE00", alpha = 0.3)

plt.plot()
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x = y_train, y = y_lr_train_pred, c = "#7CAE00", alpha = 0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')

# %% [markdown]
# # **Residual Plot**

# %%
residuals = y_train - y_lr_train_pred

plt.figure(figsize=(6,5))
plt.scatter(y_lr_train_pred, residuals, alpha=0.3)
plt.axhline(0, color="red")
plt.xlabel("Predicted")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# # **Histogram of Residuals**

# %%
plt.figure(figsize=(6,5))
plt.hist(residuals, bins=30, alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution")
plt.show()

# %% [markdown]
# # **Actual vs Predicted Line Plot**

# %%
plt.figure(figsize=(8,5))
plt.plot(y_train.values[:100], label="Actual")
plt.plot(y_lr_train_pred[:100], label="Predicted")
plt.legend()
plt.title("Actual vs Predicted (first 100 samples)")
plt.show()

# %% [markdown]
# # **Error Bar Plot**

# %%
errors = np.abs(y_train - y_lr_train_pred)

plt.figure(figsize=(8,5))
plt.plot(errors[:100])
plt.title("Absolute Errors (first 100)")
plt.xlabel("Sample Index")
plt.ylabel("Absolute Error")
plt.show()

# %% [markdown]
# # **Predicted vs Actual with Perfect Line (Best Visualization)**

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_train, y_lr_train_pred, alpha=0.3)
plt.plot([y_train.min(), y_train.max()],
         [y_train.min(), y_train.max()],
         color="red", linewidth=2)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Perfect Fit Line)")
plt.show()

# %% [markdown]
# # **Boxplot of Errors**

# %%
plt.figure(figsize=(5,5))
plt.boxplot(residuals)
plt.title("Boxplot of Residuals")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# # **Feature Importance Graph (For Random Forest)**
#
# ---

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
import pandas as pd

importance = rf_model.feature_importances_
feat_imp = pd.Series(importance, index=X_train.columns).sort_values(ascending=False)

plt.figure(figsize=(8,5))
feat_imp.head(10).plot(kind="bar")
plt.title("Top 10 Feature Importances (Random Forest)")
plt.show()

# %% [markdown]
# # **Compare Models Graph (Bar Chart)**

# %%
print(df_models.columns)
# Out:
# Index(['Metnod', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'], dtype='object')

# %%
df_models.columns = df_models.columns.str.strip()
print(df_models.columns)
# Out:
# Index(['Metnod', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2'], dtype='object')

# %%
plt.figure(figsize=(6,4))
plt.bar(df_models["Method"], df_models["Test R2"])
plt.title("Model Comparison (Test R2)")
plt.ylabel("R2 Score")
plt.show()

# %% [markdown]
# # **Cross Validation Score**

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, X, y, cv=5, scoring="r2")
print("CV R2 Scores:", scores)
print("Mean R2:", scores.mean())
# Out:
# CV R2 Scores: [0.80779501 0.70804907 0.80174754 0.76502213 0.65669052]
# Mean R2: 0.7478608541691425

# %% [markdown]
# # **Hyperparameter Tuning (Random Forest)**

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [None, 5, 10]
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, cv=3, scoring="r2")
grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Best Params: {'max_depth': None, 'n_estimators': 200}
# Best Score: 0.8714712387168347

# %% [markdown]
# # **Save Model**

# %%
import joblib
joblib.dump(rf_model, "random_forest_model.pkl")
# Out:
# ['random_forest_model.pkl']

# %%
import joblib

rf_model = joblib.load("random_forest_model.pkl")
print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!

# %%
import pandas as pd

my_data = pd.DataFrame([[1254785, 6451546, 26484154, 6165161]], columns=X_train.columns)

prediction = rf_model.predict(my_data)
print("Predicted LogS:", prediction[0])
# Out:
# Predicted LogS: -7.732621666666668

# %% [markdown]
# # **Create a sample CSV file for testing (10 rows from X_test)**

# %%
# Create a sample CSV file for testing (10 rows from X_test)
sample_data = X_test.head(10)

sample_data.to_csv("my_test_data.csv", index=False)

print("CSV file created: my_test_data.csv")
# Out:
# CSV file created: my_test_data.csv

# %%
my_data = pd.read_csv("my_test_data.csv")

prediction = rf_model.predict(my_data)
print(prediction)
# Out:
# [-3.24907    -8.07645075 -2.23658667 -1.42745667 -0.48579    -1.94287
#   0.0172     -2.02684    -6.29234905 -4.04910667]

# %%
my_data["Predicted_LogS"] = rf_model.predict(my_data)

my_data.to_csv("predicted_results.csv", index=False)
print("Saved predictions to predicted_results.csv")
# Out:
# Saved predictions to predicted_results.csv

# %%
import pandas as pd
import joblib

rf_model = joblib.load("random_forest_model.pkl")

my_data = pd.read_csv("my_test_data.csv")

predictions = rf_model.predict(my_data)

my_data["Predicted_LogS"] = predictions

my_data.to_csv("predicted_results.csv", index=False)

print("Prediction saved in predicted_results.csv")
# Out:
# Prediction saved in predicted_results.csv

# %% [markdown]
# # **Single code to print all graphs **

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score

# -----------------------------
# Select your model here
# -----------------------------
model = rf   # change this to lr if using Linear Regression

# -----------------------------
# Predictions
# -----------------------------
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# -----------------------------
# Metrics
# -----------------------------
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("MODEL PERFORMANCE REPORT")
print("------------------------")
print("Training MSE:", train_mse)
print("Test MSE:", test_mse)
print("Training R2:", train_r2)
print("Test R2:", test_r2)
print("\n\n")

# -----------------------------
# Residuals
# -----------------------------
train_residuals = y_train - y_train_pred
test_residuals = y_test - y_test_pred


# =====================================================
# GRAPH 1: Actual vs Predicted (Train)
# =====================================================
plt.figure(figsize=(6,6))
plt.scatter(y_train, y_train_pred, alpha=0.3)
plt.plot([y_train.min(), y_train.max()],
         [y_train.min(), y_train.max()],
         color="red", linewidth=2)
plt.xlabel("Actual (Train)")
plt.ylabel("Predicted (Train)")
plt.title("Actual vs Predicted (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 2: Actual vs Predicted (Test)
# =====================================================
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_test_pred, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color="red", linewidth=2)
plt.xlabel("Actual (Test)")
plt.ylabel("Predicted (Test)")
plt.title("Actual vs Predicted (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 3: Residual Plot (Train)
# =====================================================
plt.figure(figsize=(6,5))
plt.scatter(y_train_pred, train_residuals, alpha=0.3)
plt.axhline(0, color="red", linewidth=2)
plt.xlabel("Predicted (Train)")
plt.ylabel("Residuals")
plt.title("Residual Plot (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 4: Residual Plot (Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.scatter(y_test_pred, test_residuals, alpha=0.3)
plt.axhline(0, color="red", linewidth=2)
plt.xlabel("Predicted (Test)")
plt.ylabel("Residuals")
plt.title("Residual Plot (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 5: Histogram of Residuals (Train)
# =====================================================
plt.figure(figsize=(6,5))
plt.hist(train_residuals, bins=30, alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 6: Histogram of Residuals (Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.hist(test_residuals, bins=30, alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 7: Error Magnitude Plot (Test)
# =====================================================
abs_errors = np.abs(y_test - y_test_pred)

plt.figure(figsize=(8,5))
plt.plot(abs_errors[:100])
plt.title("Absolute Errors (First 100 Test Samples)")
plt.xlabel("Sample Index")
plt.ylabel("Absolute Error")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 8: Boxplot of Residuals (Train vs Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.boxplot([train_residuals, test_residuals], tick_labels=["Train", "Test"])
plt.title("Boxplot of Residuals")
plt.ylabel("Residuals")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 9: Feature Importance (Only for Random Forest)
# =====================================================
if hasattr(model, "feature_importances_"):
    importance = model.feature_importances_
    feat_imp = pd.Series(importance, index=X_train.columns).sort_values(ascending=False)

    plt.figure(figsize=(10,5))
    feat_imp.head(15).plot(kind="bar")
    plt.title("Top 15 Feature Importances")
    plt.xlabel("Features")
    plt.ylabel("Importance")
    plt.show()
    plt.close()
    print("\n\n")
else:
    print("Feature Importance not available for this model (only works for tree models).")
# Out:
# MODEL PERFORMANCE REPORT
# ------------------------
# Training MSE: 1.028227802112806
# Test MSE: 1.407688264904896
# Training R2: 0.7596688824431413
# Test R2: 0.7092230211002489

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score

# -----------------------------
# Select your model here
# -----------------------------
model = lr   # change this to lr if using Linear Regression

# -----------------------------
# Predictions
# -----------------------------
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# -----------------------------
# Metrics
# -----------------------------
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("MODEL PERFORMANCE REPORT")
print("------------------------")
print("Training MSE:", train_mse)
print("Test MSE:", test_mse)
print("Training R2:", train_r2)
print("Test R2:", test_r2)
print("\n\n")

# -----------------------------
# Residuals
# -----------------------------
train_residuals = y_train - y_train_pred
test_residuals = y_test - y_test_pred


# =====================================================
# GRAPH 1: Actual vs Predicted (Train)
# =====================================================
plt.figure(figsize=(6,6))
plt.scatter(y_train, y_train_pred, alpha=0.3)
plt.plot([y_train.min(), y_train.max()],
         [y_train.min(), y_train.max()],
         color="red", linewidth=2)
plt.xlabel("Actual (Train)")
plt.ylabel("Predicted (Train)")
plt.title("Actual vs Predicted (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 2: Actual vs Predicted (Test)
# =====================================================
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_test_pred, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color="red", linewidth=2)
plt.xlabel("Actual (Test)")
plt.ylabel("Predicted (Test)")
plt.title("Actual vs Predicted (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 3: Residual Plot (Train)
# =====================================================
plt.figure(figsize=(6,5))
plt.scatter(y_train_pred, train_residuals, alpha=0.3)
plt.axhline(0, color="red", linewidth=2)
plt.xlabel("Predicted (Train)")
plt.ylabel("Residuals")
plt.title("Residual Plot (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 4: Residual Plot (Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.scatter(y_test_pred, test_residuals, alpha=0.3)
plt.axhline(0, color="red", linewidth=2)
plt.xlabel("Predicted (Test)")
plt.ylabel("Residuals")
plt.title("Residual Plot (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 5: Histogram of Residuals (Train)
# =====================================================
plt.figure(figsize=(6,5))
plt.hist(train_residuals, bins=30, alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution (Training Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 6: Histogram of Residuals (Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.hist(test_residuals, bins=30, alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residual Distribution (Test Data)")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 7: Error Magnitude Plot (Test)
# =====================================================
abs_errors = np.abs(y_test - y_test_pred)

plt.figure(figsize=(8,5))
plt.plot(abs_errors[:100])
plt.title("Absolute Errors (First 100 Test Samples)")
plt.xlabel("Sample Index")
plt.ylabel("Absolute Error")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 8: Boxplot of Residuals (Train vs Test)
# =====================================================
plt.figure(figsize=(6,5))
plt.boxplot([train_residuals, test_residuals], tick_labels=["Train", "Test"])
plt.title("Boxplot of Residuals")
plt.ylabel("Residuals")
plt.show()
plt.close()
print("\n\n")


# =====================================================
# GRAPH 9: Feature Importance (Only for Random Forest)
# =====================================================
if hasattr(model, "feature_importances_"):
    importance = model.feature_importances_
    feat_imp = pd.Series(importance, index=X_train.columns).sort_values(ascending=False)

    plt.figure(figsize=(10,5))
    feat_imp.head(15).plot(kind="bar")
    plt.title("Top 15 Feature Importances")
    plt.xlabel("Features")
    plt.ylabel("Importance")
    plt.show()
    plt.close()
    print("\n\n")
else:
    print("Feature Importance not available for this model (only works for tree models).")
# Out:
# MODEL PERFORMANCE REPORT
# ------------------------
# Training MSE: 1.0075362951093687
# Test MSE: 1.0206953660861033
# Training R2: 0.7645051774663391
# Test R2: 0.7891616188563282
# Feature Importance not available for this model (only works for tree models).
